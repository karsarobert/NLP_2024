# %% [markdown]
# <a href="https://colab.research.google.com/github/karsarobert/NLP_2024/blob/main/05/NLP2024_05_01_Feladatokkal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k

# %% [markdown]
# #Vizsgáljuk meg az archivumot
#
# https://www.origo.hu/hirarchivum/2024/01/02

# %% [markdown]
# #Generáljunk linkeket az adatok letöltéséhez

# %%
# Importáljuk a datetime modult, amely segít kezelni a dátumokat
import datetime

# Létrehozunk egy üres listát az url-ek tárolására
urls = []

# Létrehozunk egy datetime objektumot 2023. január 1-jével
date = datetime.date(2024, 1, 1)

# Létrehozunk egy másik datetime objektumot 2024. január 1-jével
end_date = datetime.date(2024, 1, 2)

# Végigmegyünk a dátumokon egy napos lépésekkel, amíg el nem érjük a végdátumot
while date < end_date:
    # Kinyerjük a dátum évét, hónapját és napját
    year = date.year
    month = date.month
    day = date.day
    # Összerakjuk az url-t a dátummal
    url = f"https://www.origo.hu/hirarchivum/{year}/{month}/{day}"
    # Hozzáadjuk az url-t a listához
    urls.append(url)
    # Növeljük a dátumot egy nappal
    date += datetime.timedelta(days=1)

# Kiírjuk az url-ek listáját
print(urls)
# Out:
# ['https://www.origo.hu/hirarchivum/2024/1/1']

# %% [markdown]
# A szükséges csomagok betöltése

# %%
from newspaper import Article
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #Kérjünk le egy weboldalt

# %%
response =
# Out:
# '<!DOCTYPE html><html lang="hu"><head>\n    <base href="/">\n    <title>Hónap hírei | origo.hu</title>\n    <meta charset="utf-8">\n    <meta name="robots" content="index, follow">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\n    <link rel="manifest" href="/manifest.json">\n    <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#001592">\n    <link rel="shortcut icon" href="/favicon.ico">\n    <meta name="msapplication-TileColor" content="#001592">\n    <meta name="msapplication-config" content="/browserconfig.xml">\n    <meta name="theme-color" content="#001592">\n    <link rel="preconnect" href="https://fonts.gstatic.com">\n    <script class="structured-data" type="appli
# ...

# %% [markdown]
# #Adjuk át a BeautifulSoup-nak elemzésre.

# %%
soup =

# %% [markdown]
# #Keressük meg benne a lehetséges cikkek címeit, ezek linkek, hivatkozások

# %%
 links =

# %% [markdown]
# #Milyen típusú az objektum?

# %%
type(links)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# #Ellenőrízzük le egy elemét

# %%
links[68]
# Out:
# <a _ngcontent-sc337="" href="/itthon/2024/01/143-szor-riasztottak-a-tuzoltokat-szilveszterkor"><span _ngcontent-sc337="" class="categorized-article-container-publish-date">hétfő, 08:38</span><h2 _ngcontent-sc337="" class="categorized-article-container-title">Többen meghaltak szilveszter éjjel lakástűzben Magyarországon</h2></a>

# %% [markdown]
# #Keressük meg a cikk címét

# %%
title =

# %% [markdown]
# #Keressük meg a cikkhez tartozó linket

# %%
href =

# %% [markdown]
# #Adjuk át az Article-nek, töltsük le

# %%
article =
# Out:
# <bound method Article.parse of <newspaper.article.Article object at 0x7d5590137f10>>

# %% [markdown]
# #Írjuk ki a cikk szövegét

# %%
article_text = article.text
article_text
